# %%
import numpy as np
import requests
import re
import copy
from collections import Counter
import networkx as nx
import plotly
import IPython

plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Get Input

# %%
sessionId = "os.environ["ADVENT_OF_CODE_SESSION_ID"]"

# %%
r = requests.get("https://adventofcode.com/2018/day/10/input", cookies={"session": sessionId})

# %%
r.content.splitlines()
# Out:
# [b'position=< 21992, -10766> velocity=<-2,  1>',
#  b'position=<-43366, -21661> velocity=< 4,  2>',
#  b'position=<-10714, -21661> velocity=< 1,  2>',
#  b'position=< 21993,  32773> velocity=<-2, -3>',
#  b'position=< 43745,  32772> velocity=<-4, -3>',
#  b'position=< 43742,  43664> velocity=<-4, -4>',
#  b'position=<-43327,  43662> velocity=< 4, -4>',
#  b'position=<-43373,  43655> velocity=< 4, -4>',
#  b'position=<-10677,  32773> velocity=< 1, -3>',
#  b'position=<-43324,  43664> velocity=< 4, -4>',
#  b'position=<-32447,  43664> velocity=< 3, -4>',
#  b'position=< 21946, -54317> velocity=<-2,  5>',
#  b'position=< 11051, -10772> velocity=<-1,  1>',
#  b'position=< 32824, -21652> velocity=<-3,  2>',
#  b'position=< 11092, -21655> velocity=<-1,  2>',
#  b'position=< 32863,  11002> velocity=<-3, -1>',
#  b'position=<-21562,  10997> velocity=< 2, -1>',
#  b'position=<-10725,  43662> velocity=< 1, -4>',
#  b'position=< 11074,  11006> velocity=<-1, -1>',
#  b'position=<-54209, -10768> velocity=< 5,  1>',
#  b'position=< 43710, -10774> velocity=<-4,  1>',
#  b'position=< 54615,  54544> velocity=<-5, -5>',
#  b'position=< 32859, -21659> velocity=<-3,  2>',
#  b'position=< 11052,  10997> velocity=<-1, -1>',
#  b'position=< 21957, -32542> velocity=<-2,  3>',
#  b'position=<-10714,  10997> velocity=< 1, -1>',
#  b'position=< 32847, -21652> velocity=<-3,  2>',
#  b'position=<-21561, -32547> velocity=< 2,  3>',
#  b'position=< 11074,  21887> velocity=<-1, -2>',
#  b'position=<-43339, -21656> velocity=< 4,  2>',
#  b'position=< 54643,  54541> velocity=<-5, -5>',
#  b'position=<-32477, -32547> velocity=< 3,  3>',
#  b'position=<-21571,  11005> velocity=< 2, -1>',
#  b'position=<-10701, -54314> velocity=< 1,  5>',
#  b'position=<-21584, -43429> velocity=< 2,  4>',
#  b'position=<-21595, -32542> velocity=< 2,  3>',
#  b'position=< 54594,  21887> velocity=<-5, -2>',
#  b'position=< 21970,  32774> velocity=<-2, -3>',
#  b'position=<-54237, -43425> velocity=< 5,  4>',
#  b'position=< 43732, -54319> velocity=<-4,  5>',
#  b'position=<-32488, -10766> velocity=< 3,  1>',
#  b'position=<-32473, -43433> velocity=< 3,  4>',
#  b'position=<-43370,  10998> velocity=< 4, -1>',
#  b'position=<-43347,  32777> velocity=< 4, -3>',
#  b'position=<-32460,  11002> velocity=< 3, -1>',
#  b'position=< 21962, -21659> velocity=<-2,  2>',
#  b'position=< 21981,  21889> velocity=<-2, -2>',
#  b'position=<-32437, -21656> velocity=< 3,  2>',
#  b'position=<-43347, -21653> velocity=< 4,  2>',
#  b'position=< 54652,  54541> velocity=<-5, -5>',
#  b'position=<-21606, -54319> velocity=< 2,  5>',
#  b'position=< 11055,  54549> velocity=<-1, -5>',
#  b'position=<-54259,  21892> velocity=< 5, -2>',
#  b'position=< 54636,  32777> velocity=<-5, -3>',
#  b'position=<-54224,  11006> velocity=< 5, -1>',
#  b'position=<-10723, -54310> velocity=< 1,  5>',
#  b'position=< 32856,  54547> velocity=<-3, -5>',
#  b'position=< 11052,  11006> velocity=<-1, -1>',
#  b'position=<-10674, -54319> velocity=< 1,  5>',
#  b'position=< 11071, -54317> velocity=<-1,  5>',
#  b'position=< 11075,  54541> velocity=<-1, -5>',
#  b'position=<-54226,  21888> velocity=< 5, -2>',
#  b'position=< 21962,  32774> velocity=<-2, -3>',
#  b'position=<-54251,  21883> velocity=< 5, -2>',
#  b'position=< 54628, -32540> velocity=<-5,  3>',
#  b'position=< 11087,  32770> velocity=<-1, -3>',
#  b'position=< 54594,  43659> velocity=<-5, -4>',
#  b'position=< 43748,  32778> velocity=<-4, -3>',
#  b'position=< 32854,  32778> velocity=<-3, -3>',
#  b'position=< 54639, -32542> velocity=<-5,  3>',
#  b'position=<-43367, -43425> velocity=< 4,  4>',
#  b'position=< 54651, -21660> velocity=<-5,  2>',
#  b'position=< 11087,  10999> velocity=<-1, -1>',
#  b'position=<-43379,  32778> velocity=< 4, -3>',
#  b'position=< 43737, -32543> velocity=<-4,  3>',
#  b'position=<-43382,  43655> velocity=< 4, -4>',
#  b'position=<-10684, -43433> velocity=< 1,  4>',
#  b'position=<-54250,  54550> velocity=< 5, -5>',
#  b'position=< 11095, -21657> velocity=<-1,  2>',
#  b'position=< 32836,  10997> velocity=<-3, -1>',
#  b'position=<-54209, -32540> velocity=< 5,  3>',
#  b'position=< 11050,  21892> velocity=<-1, -2>',
#  b'position=<-21587,  10999> velocity=< 2, -1>',
#  b'position=< 43725,  54550> velocity=<-4, -5>',
#  b'position=<-54221,  32771> velocity=< 5, -3>',
#  b'position=< 11087,  54546> velocity=<-1, -5>',
#  b'position=< 11088, -32538> velocity=<-1,  3>',
#  b'position=< 21986, -10774> velocity=<-2,  1>',
#  b'position=< 11071,  10998> velocity=<-1, -1>',
#  b'position=< 54631,  43661> velocity=<-5, -4>',
#  b'position=<-32462,  21892> velocity=< 3, -2>',
#  b'position=<-32464, -43433> velocity=< 3,  4>',
#  b'position=<-32485, -10772> velocity=< 3,  1>',
#  b'position=< 43707,  21888> velocity=<-4, -2>',
#  b'position=< 54602, -32538> velocity=<-5,  3>',
#  b'position=<-43335, -32546> velocity=< 4,  3>',
#  b'position=< 54639, -10769> velocity=<-5,  1>',
#  b'position=<-21551, -21656> velocity=< 2,  2>',
#  b'position=<-43323, -21658> velocity=< 4,  2>',
#  b'position=< 43718,  32770> velocity=<-4, -3>',
#  b'position=<-10709,  43662> velocity=< 1, -4>',
#  b'position=< 43749,  10997> velocity=<-4, -1>',
#  b'position=< 32859,  11002> velocity=<-3, -1>',
#  b'position=< 32839, -43433> velocity=<-3,  4>',
#  b'position=< 21975, -10775> velocity=<-2,  1>',
#  b'position=< 11088,  11006> velocity=<-1, -1>',
#  b'position=<-10716,  21892> velocity=< 1, -2>',
#  b'position=<-21560, -32538> velocity=< 2,  3>',
#  b'position=<-21591,  54541> velocity=< 2, -5>',
#  b'position=< 21968, -21661> velocity=<-2,  2>',
#  b'position=<-21579, -32545> velocity=< 2,  3>',
#  b'position=<-10721, -32547> velocity=< 1,  3>',
#  b'position=<-32468, -43430> velocity=< 3,  4>',
#  b'position=<-54260, -43427> velocity=< 5,  4>',
#  b'position=<-43333,  10997> velocity=< 4, -1>',
#  b'position=<-21579,  21884> velocity=< 2, -2>',
#  b'position=<-43343,  54545> velocity=< 4, -5>',
#  b'position=<-10708, -43424> velocity=< 1,  4>',
#  b'position=< 54601, -21661> velocity=<-5,  2>',
#  b'position=<-32460, -21654> velocity=< 3,  2>',
#  b'position=< 32848, -10770> velocity=<-3,  1>',
#  b'position=<-54209,  21886> velocity=< 5, -2>',
#  b'position=< 32844,  32773> velocity=<-3, -3>',
#  b'position=< 32839,  32778> velocity=<-3, -3>',
#  b'position=<-43374, -43427> velocity=< 4,  4>',
#  b'position=< 32827,  43662> velocity=<-3, -4>',
#  b'position=<-21583, -43433> velocity=< 2,  4>',
#  b'position=< 32819, -54311> velocity=<-3,  5>',
#  b'position=<-43371,  43655> velocity=< 4, -4>',
#  b'position=<-32437,  10997> velocity=< 3, -1>',
#  b'position=<-21566,  43664> velocity=< 2, -4>',
#  b'position=<-43371, -21658> velocity=< 4,  2>',
#  b'position=< 43707, -32542> velocity=<-4,  3>',
#  b'position=<-21551,  11003> velocity=< 2, -1>',
#  b'position=<-21599,  11006> velocity=< 2, -1>',
#  b'position=< 11057,  43660> velocity=<-1, -4>',
#  b'position=<-21571, -10773> velocity=< 2,  1>',
#  b'position=< 54609, -43424> velocity=<-5,  4>',
#  b'position=<-32473, -54311> velocity=< 3,  5>',
#  b'position=<-21587, -54310> velocity=< 2,  5>',
#  b'position=<-43370, -54310> velocity=< 4,  5>',
#  b'position=< 54627,  21883> velocity=<-5, -2>',
#  b'position=< 54620,  32777> velocity=<-5, -3>',
#  b'position=<-32473, -54316> velocity=< 3,  5>',
#  b'position=< 54615,  21892> velocity=<-5, -2>',
#  b'position=<-21579, -54313> velocity=< 2,  5>',
#  b'position=<-43370, -21652> velocity=< 4,  2>',
#  b'position=<-10709, -54313> velocity=< 1,  5>',
#  b'position=< 43737,  32777> velocity=<-4, -3>',
#  b'position=< 32843,  11000> velocity=<-3, -1>',
#  b'position=<-43383, -32547> velocity=< 4,  3>',
#  b'position=<-43359,  43661> velocity=< 4, -4>',
#  b'position=<-10720, -43433> velocity=< 1,  4>',
#  b'position=< 54620,  32772> velocity=<-5, -3>',
#  b'position=< 43739,  21892> velocity=<-4, -2>',
#  b'position=< 54615,  43656> velocity=<-5, -4>',
#  b'position=<-32471,  32769> velocity=< 3, -3>',
#  b'position=<-54232,  21884> velocity=< 5, -2>',
#  b'position=< 11107, -10769> velocity=<-1,  1>',
#  b'position=<-43383,  21890> velocity=< 4, -2>',
#  b'position=< 21951,  54550> velocity=<-2, -5>',
#  b'position=< 43747, -21661> velocity=<-4,  2>',
#  b'position=<-32494, -43433> velocity=< 3,  4>',
#  b'position=<-21563, -54316> velocity=< 2,  5>',
#  b'position=<-54224,  11002> velocity=< 5, -1>',
#  b'position=<-43372, -32538> velocity=< 4,  3>',
#  b'position=<-43342, -21652> velocity=< 4,  2>',
#  b'position=< 11079,  54548> velocity=<-1, -5>',
#  b'position=< 11106, -32538> velocity=<-1,  3>',
#  b'position=<-32488, -54310> velocity=< 3,  5>',
#  b'position=< 43748,  43664> velocity=<-4, -4>',
#  b'position=< 11063,  43658> velocity=<-1, -4>',
#  b'position=<-54240,  54543> velocity=< 5, -5>',
#  b'position=< 21983,  43655> velocity=<-2, -4>',
#  b'position=<-21551,  32773> velocity=< 2, -3>',
#  b'position=<-21607, -32547> velocity=< 2,  3>',
#  b'position=<-10709, -54315> velocity=< 1,  5>',
#  b'position=< 21978,  32775> velocity=<-2, -3>',
#  b'position=< 32864, -21653> velocity=<-3,  2>',
#  b'position=<-32464,  43655> velocity=< 3, -4>',
#  b'position=< 32848, -54312> velocity=<-3,  5>',
#  b'position=< 54639,  32772> velocity=<-5, -3>',
#  b'position=<-43380, -21657> velocity=< 4,  2>',
#  b'position=<-43371,  54544> velocity=< 4, -5>',
#  b'position=< 11079, -43429> velocity=<-1,  4>',
#  b'position=< 11099,  43664> velocity=<-1, -4>',
#  b'position=< 54591, -21653> velocity=<-5,  2>',
#  b'position=<-10715, -54310> velocity=< 1,  5>',
#  b'position=< 21949, -10768> velocity=<-2,  1>',
#  b'position=<-21606,  43657> velocity=< 2, -4>',
#  b'position=<-54256, -21660> velocity=< 5,  2>',
#  b'position=<-54242, -54319> velocity=< 5,  5>',
#  b'position=< 21985, -21661> velocity=<-2,  2>',
#  b'position=<-32465, -32542> velocity=< 3,  3>',
#  b'position=<-54250, -43433> velocity=< 5,  4>',
#  b'position=< 43742,  11005> velocity=<-4, -1>',
#  b'position=<-32494, -10775> velocity=< 3,  1>',
#  b'position=< 32843,  11004> velocity=<-3, -1>',
#  b'position=<-21586,  43664> velocity=< 2, -4>',
#  b'position=<-10723,  21883> velocity=< 1, -2>',
#  b'position=<-21552, -43433> velocity=< 2,  4>',
#  b'position=<-43358, -10775> velocity=< 4,  1>',
#  b'position=< 32872, -10774> velocity=<-3,  1>',
#  b'position=<-10680, -54312> velocity=< 1,  5>',
#  b'position=<-54237, -32545> velocity=< 5,  3>',
#  b'position=< 54651,  10997> velocity=<-5, -1>',
#  b'position=<-32489, -43425> velocity=< 3,  4>',
#  b'position=<-54243, -43429> velocity=< 5,  4>',
#  b'position=< 54626, -54314> velocity=<-5,  5>',
#  b'position=< 11107, -21656> velocity=<-1,  2>',
#  b'position=<-21575,  10997> velocity=< 2, -1>',
#  b'position=< 43716,  11001> velocity=<-4, -1>',
#  b'position=<-10720,  32771> velocity=< 1, -3>',
#  b'position=< 11092,  43660> velocity=<-1, -4>',
#  b'position=< 54631, -21658> velocity=<-5,  2>',
#  b'position=< 11068,  11005> velocity=<-1, -1>',
#  b'position=< 43708, -21652> velocity=<-4,  2>',
#  b'position=<-10674, -32538> velocity=< 1,  3>',
#  b'position=< 11051,  11006> velocity=<-1, -1>',
#  b'position=< 11063, -54316> velocity=<-1,  5>',
#  b'position=< 11056,  32769> velocity=<-1, -3>',
#  b'position=<-21587,  21884> velocity=< 2, -2>',
#  b'position=< 11082,  43660> velocity=<-1, -4>',
#  b'position=< 43726,  43663> velocity=<-4, -4>',
#  b'position=< 54633,  54550> velocity=<-5, -5>',
#  b'position=< 11071,  43663> velocity=<-1, -4>',
#  b'position=<-43367,  43660> velocity=< 4, -4>',
#  b'position=<-21563,  11004> velocity=< 2, -1>',
#  b'position=< 54639,  54542> velocity=<-5, -5>',
#  b'position=< 32848, -32541> velocity=<-3,  3>',
#  b'position=<-54209,  54543> velocity=< 5, -5>',
#  b'position=<-43370,  21892> velocity=< 4, -2>',
#  b'position=< 54627, -21661> velocity=<-5,  2>',
#  b'position=< 54612,  54542> velocity=<-5, -5>',
#  b'position=< 11103,  43663> velocity=<-1, -4>',
#  b'position=< 32876,  21892> velocity=<-3, -2>',
#  b'position=< 21978, -21660> velocity=<-2,  2>',
#  b'position=< 54592,  54547> velocity=<-5, -5>',
#  b'position=<-43354, -43428> velocity=< 4,  4>',
#  b'position=< 54615,  11001> velocity=<-5, -1>',
#  b'position=<-10665, -43430> velocity=< 1,  4>',
#  b'position=<-21566, -10766> velocity=< 2,  1>',
#  b'position=< 43753, -43431> velocity=<-4,  4>',
#  b'position=< 43739, -32547> velocity=<-4,  3>',
#  b'position=<-43354, -43425> velocity=< 4,  4>',
#  b'position=<-10669, -21654> velocity=< 1,  2>',
#  b'position=< 54644, -10767> velocity=<-5,  1>',
#  b'position=< 54612, -43432> velocity=<-5,  4>',
#  b'position=< 32829,  54546> velocity=<-3, -5>',
#  b'position=< 54594, -10766> velocity=<-5,  1>',
#  b'position=< 54626, -32547> velocity=<-5,  3>',
#  b'position=<-32441,  11004> velocity=< 3, -1>',
#  b'position=< 43738,  11006> velocity=<-4, -1>',
#  b'position=<-43351, -32541> velocity=< 4,  3>',
#  b'position=< 43732, -10766> velocity=<-4,  1>',
#  b'position=< 43749,  32777> velocity=<-4, -3>',
#  b'position=<-32460, -21656> velocity=< 3,  2>',
#  b'position=< 54628,  10998> velocity=<-5, -1>',
#  b'position=< 21949,  32777> velocity=<-2, -3>',
#  b'position=<-43370, -21661> velocity=< 4,  2>',
#  b'position=<-10682, -43433> velocity=< 1,  4>',
#  b'position=<-32441, -10767> velocity=< 3,  1>',
#  b'position=< 21973,  21888> velocity=<-2, -2>',
#  b'position=< 21973,  11000> velocity=<-2, -1>',
#  b'position=< 11107, -10771> velocity=<-1,  1>',
#  b'position=<-10680, -10769> velocity=< 1,  1>',
#  b'position=< 32867,  54542> velocity=<-3, -5>',
#  b'position=<-10701,  21887> velocity=< 1, -2>',
#  b'position=<-54250, -10775> velocity=< 5,  1>',
#  b'position=< 54615, -10768> velocity=<-5,  1>',
#  b'position=<-21550,  21883> velocity=< 2, -2>',
#  b'position=<-43346,  21890> velocity=< 4, -2>',
#  b'position=<-54216, -54318> velocity=< 5,  5>',
#  b'position=<-43357,  11006> velocity=< 4, -1>',
#  b'position=<-10692, -10766> velocity=< 1,  1>',
#  b'position=< 21944,  21892> velocity=<-2, -2>',
#  b'position=< 54623, -10772> velocity=<-5,  1>',
#  b'position=< 43749,  43663> velocity=<-4, -4>',
#  b'position=< 43740,  21888> velocity=<-4, -2>',
#  b'position=<-54224,  32776> velocity=< 5, -3>',
#  b'position=<-54240,  43657> velocity=< 5, -4>',
#  b'position=<-21592, -54310> velocity=< 2,  5>',
#  b'position=< 54599,  21883> velocity=<-5, -2>',
#  b'position=< 32830, -10771> velocity=<-3,  1>',
#  b'position=< 21961,  54550> velocity=<-2, -5>',
#  b'position=<-54258, -32543> velocity=< 5,  3>',
#  b'position=< 11047, -10768> velocity=<-1,  1>',
#  b'position=< 11047, -21653> velocity=<-1,  2>',
#  b'position=< 43709,  21883> velocity=<-4, -2>',
#  b'position=< 43729, -10766> velocity=<-4,  1>',
#  b'position=<-32481, -54317> velocity=< 3,  5>',
#  b'position=<-32481, -54318> velocity=< 3,  5>',
#  b'position=< 43750, -54311> velocity=<-4,  5>',
#  b'position=<-43325,  11006> velocity=< 4, -1>',
#  b'position=<-43331,  21892> velocity=< 4, -2>',
#  b'position=< 32867, -54311> velocity=<-3,  5>',
#  b'position=< 32847, -10771> velocity=<-3,  1>',
#  b'position=< 43731,  43664> velocity=<-4, -4>',
#  b'position=< 21965, -10770> velocity=<-2,  1>',
#  b'position=<-43362,  21884> velocity=< 4, -2>',
#  b'position=< 43742,  43663> velocity=<-4, -4>',
#  b'position=< 54634,  54541> velocity=<-5, -5>',
#  b'position=<-32437,  10999> velocity=< 3, -1>',
#  b'position=< 54631, -21654> velocity=<-5,  2>',
#  b'position=<-54220,  11006> velocity=< 5, -1>',
#  b'position=< 54607,  54546> velocity=<-5, -5>',
#  b'position=<-43342,  43655> velocity=< 4, -4>',
#  b'position=< 21973,  32773> velocity=<-2, -3>',
#  b'position=<-32496, -32538> velocity=< 3,  3>',
#  b'position=< 54599, -21652> velocity=<-5,  2>',
#  b'position=<-54267,  54541> velocity=< 5, -5>',
#  b'position=< 21949, -10768> velocity=<-2,  1>',
#  b'position=< 11071, -10773> velocity=<-1,  1>',
#  b'position=< 32879,  54549> velocity=<-3, -5>',
#  b'position=<-43351, -54316> velocity=< 4,  5>',
#  b'position=<-54237,  10999> velocity=< 5, -1>',
#  b'position=<-54245,  32774> velocity=< 5, -3>',
#  b'position=<-43375,  54549> velocity=< 4, -5>',
#  b'position=< 54623, -21658> velocity=<-5,  2>',
#  b'position=<-43375,  32778> velocity=< 4, -3>',
#  b'position=<-21551, -21660> velocity=< 2,  2>',
#  b'position=< 43741, -21656> velocity=<-4,  2>',
#  b'position=<-54240,  32775> velocity=< 5, -3>',
#  b'position=< 21984, -10766> velocity=<-2,  1>',
#  b'position=<-10720, -21659> velocity=< 1,  2>',
#  b'position=< 32824,  32770> velocity=<-3, -3>',
#  b'position=< 11057,  32774> velocity=<-1, -3>',
#  b'position=<-21561,  54550> velocity=< 2, -5>',
#  b'position=< 11071, -21653> velocity=<-1,  2>',
#  b'position=<-32497, -54310> velocity=< 3,  5>',
#  b'position=< 32871,  43655> velocity=<-3, -4>',
#  b'position=<-43371,  32778> velocity=< 4, -3>',
#  b'position=<-21582, -54318> velocity=< 2,  5>',
#  b'position=< 11076, -21658> velocity=<-1,  2>',
#  b'position=< 43749,  43655> velocity=<-4, -4>',
#  b'position=< 43754, -54319> velocity=<-4,  5>']

# %%
def parse_particle(line):
    m = re.search('position=<\s*(-?\d+),\s*(-?\d+)> velocity=<\s*(-?\d+),\s*(-?\d+)>', line.decode('utf-8'))
    x, y, v_x, v_y = m.group(1),m.group(2),m.group(3),m.group(4)
    return int(x), int(y), int(v_x), int(v_y)

# %%
particles = [parse_particle(line) for line in r.content.splitlines()]

# %%
particles
# Out:
# [(21992, -10766, -2, 1),
#  (-43366, -21661, 4, 2),
#  (-10714, -21661, 1, 2),
#  (21993, 32773, -2, -3),
#  (43745, 32772, -4, -3),
#  (43742, 43664, -4, -4),
#  (-43327, 43662, 4, -4),
#  (-43373, 43655, 4, -4),
#  (-10677, 32773, 1, -3),
#  (-43324, 43664, 4, -4),
#  (-32447, 43664, 3, -4),
#  (21946, -54317, -2, 5),
#  (11051, -10772, -1, 1),
#  (32824, -21652, -3, 2),
#  (11092, -21655, -1, 2),
#  (32863, 11002, -3, -1),
#  (-21562, 10997, 2, -1),
#  (-10725, 43662, 1, -4),
#  (11074, 11006, -1, -1),
#  (-54209, -10768, 5, 1),
#  (43710, -10774, -4, 1),
#  (54615, 54544, -5, -5),
#  (32859, -21659, -3, 2),
#  (11052, 10997, -1, -1),
#  (21957, -32542, -2, 3),
#  (-10714, 10997, 1, -1),
#  (32847, -21652, -3, 2),
#  (-21561, -32547, 2, 3),
#  (11074, 21887, -1, -2),
#  (-43339, -21656, 4, 2),
#  (54643, 54541, -5, -5),
#  (-32477, -32547, 3, 3),
#  (-21571, 11005, 2, -1),
#  (-10701, -54314, 1, 5),
#  (-21584, -43429, 2, 4),
#  (-21595, -32542, 2, 3),
#  (54594, 21887, -5, -2),
#  (21970, 32774, -2, -3),
#  (-54237, -43425, 5, 4),
#  (43732, -54319, -4, 5),
#  (-32488, -10766, 3, 1),
#  (-32473, -43433, 3, 4),
#  (-43370, 10998, 4, -1),
#  (-43347, 32777, 4, -3),
#  (-32460, 11002, 3, -1),
#  (21962, -21659, -2, 2),
#  (21981, 21889, -2, -2),
#  (-32437, -21656, 3, 2),
#  (-43347, -21653, 4, 2),
#  (54652, 54541, -5, -5),
#  (-21606, -54319, 2, 5),
#  (11055, 54549, -1, -5),
#  (-54259, 21892, 5, -2),
#  (54636, 32777, -5, -3),
#  (-54224, 11006, 5, -1),
#  (-10723, -54310, 1, 5),
#  (32856, 54547, -3, -5),
#  (11052, 11006, -1, -1),
#  (-10674, -54319, 1, 5),
#  (11071, -54317, -1, 5),
#  (11075, 54541, -1, -5),
#  (-54226, 21888, 5, -2),
#  (21962, 32774, -2, -3),
#  (-54251, 21883, 5, -2),
#  (54628, -32540, -5, 3),
#  (11087, 32770, -1, -3),
#  (54594, 43659, -5, -4),
#  (43748, 32778, -4, -3),
#  (32854, 32778, -3, -3),
#  (54639, -32542, -5, 3),
#  (-43367, -43425, 4, 4),
#  (54651, -21660, -5, 2),
#  (11087, 10999, -1, -1),
#  (-43379, 32778, 4, -3),
#  (43737, -32543, -4, 3),
#  (-43382, 43655, 4, -4),
#  (-10684, -43433, 1, 4),
#  (-54250, 54550, 5, -5),
#  (11095, -21657, -1, 2),
#  (32836, 10997, -3, -1),
#  (-54209, -32540, 5, 3),
#  (11050, 21892, -1, -2),
#  (-21587, 10999, 2, -1),
#  (43725, 54550, -4, -5),
#  (-54221, 32771, 5, -3),
#  (11087, 54546, -1, -5),
#  (11088, -32538, -1, 3),
#  (21986, -10774, -2, 1),
#  (11071, 10998, -1, -1),
#  (54631, 43661, -5, -4),
#  (-32462, 21892, 3, -2),
#  (-32464, -43433, 3, 4),
#  (-32485, -10772, 3, 1),
#  (43707, 21888, -4, -2),
#  (54602, -32538, -5, 3),
#  (-43335, -32546, 4, 3),
#  (54639, -10769, -5, 1),
#  (-21551, -21656, 2, 2),
#  (-43323, -21658, 4, 2),
#  (43718, 32770, -4, -3),
#  (-10709, 43662, 1, -4),
#  (43749, 10997, -4, -1),
#  (32859, 11002, -3, -1),
#  (32839, -43433, -3, 4),
#  (21975, -10775, -2, 1),
#  (11088, 11006, -1, -1),
#  (-10716, 21892, 1, -2),
#  (-21560, -32538, 2, 3),
#  (-21591, 54541, 2, -5),
#  (21968, -21661, -2, 2),
#  (-21579, -32545, 2, 3),
#  (-10721, -32547, 1, 3),
#  (-32468, -43430, 3, 4),
#  (-54260, -43427, 5, 4),
#  (-43333, 10997, 4, -1),
#  (-21579, 21884, 2, -2),
#  (-43343, 54545, 4, -5),
#  (-10708, -43424, 1, 4),
#  (54601, -21661, -5, 2),
#  (-32460, -21654, 3, 2),
#  (32848, -10770, -3, 1),
#  (-54209, 21886, 5, -2),
#  (32844, 32773, -3, -3),
#  (32839, 32778, -3, -3),
#  (-43374, -43427, 4, 4),
#  (32827, 43662, -3, -4),
#  (-21583, -43433, 2, 4),
#  (32819, -54311, -3, 5),
#  (-43371, 43655, 4, -4),
#  (-32437, 10997, 3, -1),
#  (-21566, 43664, 2, -4),
#  (-43371, -21658, 4, 2),
#  (43707, -32542, -4, 3),
#  (-21551, 11003, 2, -1),
#  (-21599, 11006, 2, -1),
#  (11057, 43660, -1, -4),
#  (-21571, -10773, 2, 1),
#  (54609, -43424, -5, 4),
#  (-32473, -54311, 3, 5),
#  (-21587, -54310, 2, 5),
#  (-43370, -54310, 4, 5),
#  (54627, 21883, -5, -2),
#  (54620, 32777, -5, -3),
#  (-32473, -54316, 3, 5),
#  (54615, 21892, -5, -2),
#  (-21579, -54313, 2, 5),
#  (-43370, -21652, 4, 2),
#  (-10709, -54313, 1, 5),
#  (43737, 32777, -4, -3),
#  (32843, 11000, -3, -1),
#  (-43383, -32547, 4, 3),
#  (-43359, 43661, 4, -4),
#  (-10720, -43433, 1, 4),
#  (54620, 32772, -5, -3),
#  (43739, 21892, -4, -2),
#  (54615, 43656, -5, -4),
#  (-32471, 32769, 3, -3),
#  (-54232, 21884, 5, -2),
#  (11107, -10769, -1, 1),
#  (-43383, 21890, 4, -2),
#  (21951, 54550, -2, -5),
#  (43747, -21661, -4, 2),
#  (-32494, -43433, 3, 4),
#  (-21563, -54316, 2, 5),
#  (-54224, 11002, 5, -1),
#  (-43372, -32538, 4, 3),
#  (-43342, -21652, 4, 2),
#  (11079, 54548, -1, -5),
#  (11106, -32538, -1, 3),
#  (-32488, -54310, 3, 5),
#  (43748, 43664, -4, -4),
#  (11063, 43658, -1, -4),
#  (-54240, 54543, 5, -5),
#  (21983, 43655, -2, -4),
#  (-21551, 32773, 2, -3),
#  (-21607, -32547, 2, 3),
#  (-10709, -54315, 1, 5),
#  (21978, 32775, -2, -3),
#  (32864, -21653, -3, 2),
#  (-32464, 43655, 3, -4),
#  (32848, -54312, -3, 5),
#  (54639, 32772, -5, -3),
#  (-43380, -21657, 4, 2),
#  (-43371, 54544, 4, -5),
#  (11079, -43429, -1, 4),
#  (11099, 43664, -1, -4),
#  (54591, -21653, -5, 2),
#  (-10715, -54310, 1, 5),
#  (21949, -10768, -2, 1),
#  (-21606, 43657, 2, -4),
#  (-54256, -21660, 5, 2),
#  (-54242, -54319, 5, 5),
#  (21985, -21661, -2, 2),
#  (-32465, -32542, 3, 3),
#  (-54250, -43433, 5, 4),
#  (43742, 11005, -4, -1),
#  (-32494, -10775, 3, 1),
#  (32843, 11004, -3, -1),
#  (-21586, 43664, 2, -4),
#  (-10723, 21883, 1, -2),
#  (-21552, -43433, 2, 4),
#  (-43358, -10775, 4, 1),
#  (32872, -10774, -3, 1),
#  (-10680, -54312, 1, 5),
#  (-54237, -32545, 5, 3),
#  (54651, 10997, -5, -1),
#  (-32489, -43425, 3, 4),
#  (-54243, -43429, 5, 4),
#  (54626, -54314, -5, 5),
#  (11107, -21656, -1, 2),
#  (-21575, 10997, 2, -1),
#  (43716, 11001, -4, -1),
#  (-10720, 32771, 1, -3),
#  (11092, 43660, -1, -4),
#  (54631, -21658, -5, 2),
#  (11068, 11005, -1, -1),
#  (43708, -21652, -4, 2),
#  (-10674, -32538, 1, 3),
#  (11051, 11006, -1, -1),
#  (11063, -54316, -1, 5),
#  (11056, 32769, -1, -3),
#  (-21587, 21884, 2, -2),
#  (11082, 43660, -1, -4),
#  (43726, 43663, -4, -4),
#  (54633, 54550, -5, -5),
#  (11071, 43663, -1, -4),
#  (-43367, 43660, 4, -4),
#  (-21563, 11004, 2, -1),
#  (54639, 54542, -5, -5),
#  (32848, -32541, -3, 3),
#  (-54209, 54543, 5, -5),
#  (-43370, 21892, 4, -2),
#  (54627, -21661, -5, 2),
#  (54612, 54542, -5, -5),
#  (11103, 43663, -1, -4),
#  (32876, 21892, -3, -2),
#  (21978, -21660, -2, 2),
#  (54592, 54547, -5, -5),
#  (-43354, -43428, 4, 4),
#  (54615, 11001, -5, -1),
#  (-10665, -43430, 1, 4),
#  (-21566, -10766, 2, 1),
#  (43753, -43431, -4, 4),
#  (43739, -32547, -4, 3),
#  (-43354, -43425, 4, 4),
#  (-10669, -21654, 1, 2),
#  (54644, -10767, -5, 1),
#  (54612, -43432, -5, 4),
#  (32829, 54546, -3, -5),
#  (54594, -10766, -5, 1),
#  (54626, -32547, -5, 3),
#  (-32441, 11004, 3, -1),
#  (43738, 11006, -4, -1),
#  (-43351, -32541, 4, 3),
#  (43732, -10766, -4, 1),
#  (43749, 32777, -4, -3),
#  (-32460, -21656, 3, 2),
#  (54628, 10998, -5, -1),
#  (21949, 32777, -2, -3),
#  (-43370, -21661, 4, 2),
#  (-10682, -43433, 1, 4),
#  (-32441, -10767, 3, 1),
#  (21973, 21888, -2, -2),
#  (21973, 11000, -2, -1),
#  (11107, -10771, -1, 1),
#  (-10680, -10769, 1, 1),
#  (32867, 54542, -3, -5),
#  (-10701, 21887, 1, -2),
#  (-54250, -10775, 5, 1),
#  (54615, -10768, -5, 1),
#  (-21550, 21883, 2, -2),
#  (-43346, 21890, 4, -2),
#  (-54216, -54318, 5, 5),
#  (-43357, 11006, 4, -1),
#  (-10692, -10766, 1, 1),
#  (21944, 21892, -2, -2),
#  (54623, -10772, -5, 1),
#  (43749, 43663, -4, -4),
#  (43740, 21888, -4, -2),
#  (-54224, 32776, 5, -3),
#  (-54240, 43657, 5, -4),
#  (-21592, -54310, 2, 5),
#  (54599, 21883, -5, -2),
#  (32830, -10771, -3, 1),
#  (21961, 54550, -2, -5),
#  (-54258, -32543, 5, 3),
#  (11047, -10768, -1, 1),
#  (11047, -21653, -1, 2),
#  (43709, 21883, -4, -2),
#  (43729, -10766, -4, 1),
#  (-32481, -54317, 3, 5),
#  (-32481, -54318, 3, 5),
#  (43750, -54311, -4, 5),
#  (-43325, 11006, 4, -1),
#  (-43331, 21892, 4, -2),
#  (32867, -54311, -3, 5),
#  (32847, -10771, -3, 1),
#  (43731, 43664, -4, -4),
#  (21965, -10770, -2, 1),
#  (-43362, 21884, 4, -2),
#  (43742, 43663, -4, -4),
#  (54634, 54541, -5, -5),
#  (-32437, 10999, 3, -1),
#  (54631, -21654, -5, 2),
#  (-54220, 11006, 5, -1),
#  (54607, 54546, -5, -5),
#  (-43342, 43655, 4, -4),
#  (21973, 32773, -2, -3),
#  (-32496, -32538, 3, 3),
#  (54599, -21652, -5, 2),
#  (-54267, 54541, 5, -5),
#  (21949, -10768, -2, 1),
#  (11071, -10773, -1, 1),
#  (32879, 54549, -3, -5),
#  (-43351, -54316, 4, 5),
#  (-54237, 10999, 5, -1),
#  (-54245, 32774, 5, -3),
#  (-43375, 54549, 4, -5),
#  (54623, -21658, -5, 2),
#  (-43375, 32778, 4, -3),
#  (-21551, -21660, 2, 2),
#  (43741, -21656, -4, 2),
#  (-54240, 32775, 5, -3),
#  (21984, -10766, -2, 1),
#  (-10720, -21659, 1, 2),
#  (32824, 32770, -3, -3),
#  (11057, 32774, -1, -3),
#  (-21561, 54550, 2, -5),
#  (11071, -21653, -1, 2),
#  (-32497, -54310, 3, 5),
#  (32871, 43655, -3, -4),
#  (-43371, 32778, 4, -3),
#  (-21582, -54318, 2, 5),
#  (11076, -21658, -1, 2),
#  (43749, 43655, -4, -4),
#  (43754, -54319, -4, 5)]

# %%
particle_array = np.array(particles).T

# %%
x = particle_array[:][0]
y = particle_array[:][1]
v_x = particle_array[:][2]
v_y = particle_array[:][3]

# %% [markdown]
# # Part 1

# %%
data = [plotly.graph_objs.Scatter(
        #visible = False,
        name = '𝜈 = '+str(n),
        mode= 'markers', 
        x = x + n*v_x,
        y =  - y - n*v_y) for n in np.arange(10880,10900,1)]

# %%
#fig = dict(data=data[0])

#plotly.offline.iplot([data[38]])

# %%
steps = []
for i in range(len(data)):
    step = dict(
        args = ['visible', [False] * len(data)],
    )
    #print(step['args'])
    step['args'][1][i] = True # Toggle i'th trace to "visible"
    steps.append(step)
    #print(step['args'][1])

sliders = [dict(
    active = 0,
    currentvalue = {"prefix": "Step: "},
    pad = {"t": 50},
    steps = steps
)]

layout = dict(sliders=sliders)

fig = dict(data=data, layout=layout)

plotly.offline.iplot(fig)
# Out:
# <div id="f6f4d10b-2118-4e0a-8e9a-9bec1f55fb71" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f6f4d10b-2118-4e0a-8e9a-9bec1f55fb71", [{"type": "scatter", "name": "\ud835\udf08 = 10880", "mode": "markers", "x": [232, 154, 166, 233, 225, 222, 193, 147, 203, 196, 193, 186, 171, 184, 212, 223, 198, 155, 194, 191, 190, 215, 219, 172, 197, 166, 207, 199, 194, 181, 243, 163, 189, 179, 176, 165, 194, 210, 163, 212, 152, 167, 150, 173, 180, 202, 221, 203, 173, 252, 154, 175, 141, 236, 176, 157, 216, 172, 206, 191, 195, 174, 202, 149, 228, 207, 194, 228, 214, 239, 153, 251, 207, 141, 217, 138, 196, 150, 215, 196, 191, 170, 173, 205, 179, 207, 208, 226, 191, 231, 178, 176, 155, 187, 202, 185, 239, 209, 197, 198, 171, 229, 219, 199, 215, 208, 164, 200, 169, 208, 181, 159, 172, 140, 187, 181, 177, 172, 201, 180, 208, 191, 204, 199, 146, 187, 177, 179, 149, 203, 194, 149, 187, 209, 161, 177, 189, 209, 167, 173, 150, 227, 220, 167, 215, 181, 150, 171, 217, 203, 137, 161, 160, 220, 219, 215, 169, 168, 227, 137, 191, 227, 146, 197, 176, 148, 178, 199, 226, 152, 228, 183, 160, 223, 209, 153, 171, 218, 224, 176, 208, 239, 140, 149, 199, 219, 191, 165, 189, 154, 144, 158, 225, 175, 150, 222, 146, 203, 174, 157, 208, 162, 232, 200, 163, 251, 151, 157, 226, 227, 185, 196, 160, 212, 231, 188, 188, 206, 171, 183, 176, 173, 202, 206, 233, 191, 153, 197, 239, 208, 191, 150, 227, 212, 223, 236, 218, 192, 166, 215, 215, 194, 233, 219, 166, 211, 244, 212, 189, 194, 226, 199, 218, 169, 212, 229, 180, 228, 189, 150, 198, 199, 213, 213, 227, 200, 227, 179, 150, 215, 210, 174, 184, 163, 188, 184, 223, 229, 220, 176, 160, 168, 199, 190, 201, 142, 167, 167, 189, 209, 159, 159, 230, 195, 189, 227, 207, 211, 205, 158, 222, 234, 203, 231, 180, 207, 178, 213, 144, 199, 133, 189, 191, 239, 169, 163, 155, 145, 223, 145, 209, 221, 160, 224, 160, 184, 177, 199, 191, 143, 231, 149, 178, 196, 229, 234], "y": [-114, -99, -99, -133, -132, -144, -142, -135, -133, -144, -144, -83, -108, -108, -105, -122, -117, -142, -126, -112, -106, -144, -101, -117, -98, -117, -108, -93, -127, -104, -141, -93, -125, -86, -91, -98, -127, -134, -95, -81, -114, -87, -118, -137, -122, -101, -129, -104, -107, -141, -81, -149, -132, -137, -126, -90, -147, -126, -81, -83, -141, -128, -134, -123, -100, -130, -139, -138, -138, -98, -95, -100, -119, -138, -97, -135, -87, -150, -103, -117, -100, -132, -119, -150, -131, -146, -102, -106, -118, -141, -132, -87, -108, -128, -102, -94, -111, -104, -102, -130, -142, -117, -122, -87, -105, -126, -132, -102, -141, -99, -95, -93, -90, -93, -117, -124, -145, -96, -99, -106, -110, -126, -133, -138, -93, -142, -87, -89, -135, -117, -144, -102, -98, -123, -126, -140, -107, -96, -89, -90, -90, -123, -137, -84, -132, -87, -108, -87, -137, -120, -93, -141, -87, -132, -132, -136, -129, -124, -111, -130, -150, -99, -87, -84, -122, -102, -108, -148, -102, -90, -144, -138, -143, -135, -133, -93, -85, -135, -107, -135, -88, -132, -103, -144, -91, -144, -107, -90, -112, -137, -100, -81, -99, -98, -87, -125, -105, -124, -144, -123, -87, -105, -106, -88, -95, -117, -95, -91, -86, -104, -117, -121, -131, -140, -102, -125, -108, -102, -126, -84, -129, -124, -140, -143, -150, -143, -140, -124, -142, -99, -143, -132, -99, -142, -143, -132, -100, -147, -92, -121, -90, -114, -89, -93, -95, -106, -113, -88, -146, -114, -93, -124, -126, -99, -114, -137, -104, -118, -137, -99, -87, -113, -128, -120, -109, -111, -142, -127, -105, -112, -123, -130, -82, -126, -114, -132, -108, -143, -128, -136, -137, -90, -123, -109, -150, -97, -112, -107, -123, -114, -83, -82, -89, -126, -132, -89, -109, -144, -110, -124, -143, -141, -119, -106, -126, -146, -135, -133, -102, -108, -141, -112, -107, -149, -84, -119, -134, -149, -102, -138, -100, -104, -135, -114, -101, -130, -134, -150, -107, -90, -135, -138, -82, ...
